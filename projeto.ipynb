# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
# 5               39807               39807                INCIDENTE
# 6               40215               40215                INCIDENTE
# 7               39707               39707          INCIDENTE GRAVE
# 8               39156               39156          INCIDENTE GRAVE
# 9               39711               39711          INCIDENTE GRAVE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BEL�M            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3    -131.066.666.667     -559.930.555.556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
# 5                 ***                  ***            SALVADOR            BA
# 6                 ***                  ***               COARI            AM
# 7     -65.319.444.444     -643.805.555.556            CANUTAMA            AM
# 8    -152.402.777.778     -593.541.666.667            CASCAVEL            PR
# 9                 ***                  ***       PAR� DE MINAS            MG
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
# 5  ...     2010-01-06        17:53:00                            ***
# 6  ...     2010-01-07        18:40:00                            SIM
# 7  ...     2010-01-09        12:30:00                            SIM
# 8  ...     2010-01-10        23:15:00                            SIM
# 9  ...     2010-01-10        20:00:00                            ***
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
# 5                 NaN                         NaN
# 6          FINALIZADA                         NaN
# 7          FINALIZADA          IG-028/CENIPA/2011
# 8          FINALIZADA           I-004/CENIPA/2011
# 9                 NaN                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            N�O                       NaN
# 1                            N�O                       NaN
# 2                            N�O                       NaN
# 3                            SIM                28/10/2019
# 4                            N�O                       NaN
# 5                            N�O                       NaN
# 6                            N�O                       NaN
# 7                            SIM                21/07/2011
# 8                            SIM                30/06/2011
# 9                            N�O                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     N�O
# 1                   0                          1                     N�O
# 2                   0                          1                     N�O
# 3                   0                          1                     N�O
# 4                   0                          1                     N�O
# 5                   0                          1                     N�O
# 6                   0                          1                     SIM
# 7                   3                          1                     N�O
# 8                   2                          1                     N�O
# 9                   0                          1                     N�O
#
# [10 rows x 22 columns]

# %%
#pa.DataFrameSchema(
#
#)

schema = pa.DataFrameSchema(
    columns = {
        "codigo":pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 6109               80245               80245                INCIDENTE
# 6110               80247               80247                INCIDENTE
# 6111               80251               80251                INCIDENTE
# 6112               80257               80257                 ACIDENTE
# 6113               80259               80259                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BEL�M
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3       -131.066.666.667     -559.930.555.556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 6109            -812.638           -3.492.277              RECIFE
# 6110  -8.713.611.111.111   -6.390.277.777.777         PORTO VELHO
# 6111  -1.384.722.222.222   -4.847.888.888.888               BEL�M
# 6112         -15.430.833          -54.699.722          DOM AQUINO
# 6113  -2.300.694.444.444   -4.713.444.444.444            CAMPINAS
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 6109            PE  ...     2021-08-15        15:05:00
# 6110            RO  ...     2021-08-16        02:30:00
# 6111            PA  ...     2021-08-17        15:45:00
# 6112            MT  ...     2021-08-18        16:00:00
# 6113            SP  ...     2021-08-18        12:45:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 6109                            SIM          FINALIZADA
# 6110                            SIM          FINALIZADA
# 6111                            SIM          FINALIZADA
# 6112                            SIM          FINALIZADA
# 6113                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            N�O
# 1                            NaN                            N�O
# 2                            NaN                            N�O
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            N�O
# ...                          ...                            ...
# 6109                         ***                            N�O
# 6110                         ***                            N�O
# 6111                         ***                            N�O
# 6112                         ***                            N�O
# 6113                         ***                            N�O
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   28/10/2019                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 6109                       NaN                   0                          1
# 6110                       NaN                   0                          1
# 6111                       NaN                   0                          1
# 6112                       NaN                   0                          1
# 6113                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        N�O
# 1                        N�O
# 2                        N�O
# 3                        N�O
# 4                        N�O
# ...                      ...
# 6109                     N�O
# 6110                     N�O
# 6111                     N�O
# 6112                     N�O
# 6113                     N�O
#
# [6114 rows x 22 columns]

# %% [markdown]
# df.dtypes
# df.ocorrencia_dia.dt.month

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %% [raw]
# pip install pandera
